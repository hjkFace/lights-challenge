# %% [markdown]
# Определять надо параметры:
#
#     Type
#     Finish1
#     Treatment
#     Hanging Method
#     Shade Color
#     Shade Shape
#     Tier
#     Style
#
# Product title - можно использовать в помощь и какие-то атрибуты, возможно, определять по нему, а не по изображению.

# %%
from __future__ import division, unicode_literals

import pandas as pd
import numpy as np
from scipy import interp
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('product_attributes.csv', encoding='utf-8', 
                    dialect='excel', lineterminator='\r')
train.tail(30)
# Out:
#        ProductID       EID      PID            VID      Department  \
# 34307  \nP994209  430656.0  P994209        46017/1  Ceiling Lights
# 34308  \nP994210  460029.0  P994210        46017/3  Ceiling Lights
# 34309  \nP994211  431937.0  P994211       46017/3L  Ceiling Lights
# 34310  \nP994212  443578.0  P994212      46017/6RC  Ceiling Lights
# 34311  \nP994213  463528.0  P994213        46018/1  Ceiling Lights
# 34312  \nP994214  429880.0  P994214        46018/3  Ceiling Lights
# 34313  \nP994215       NaN  P994215       46018/3L  Ceiling Lights
# 34314  \nP994216       NaN  P994216      46018/6RC  Ceiling Lights
# 34315  \nP994217  477313.0  P994217        14121/1  Ceiling Lights
# 34316  \nP994218       NaN  P994218     14121/1-LA  Ceiling Lights
# 34317  \nP994219  432467.0  P994219     31380/1SMK  Ceiling Lights
# 34318  \nP994220       NaN  P994220  31380/1SMK-LA  Ceiling Lights
# 34319  \nP994221       NaN  P994221   31380/3L-SMK  Ceiling Lights
# 34320  \nP994222  436218.0  P994222     31380/3SMK  Ceiling Lights
# 34321  \nP994223  543305.0  P994223  31380/6RC-SMK  Ceiling Lights
# 34322  \nP994224  427991.0  P994224        46007/1  Ceiling Lights
# 34323  \nP994225  464264.0  P994225        46007/3  Ceiling Lights
# 34324  \nP994226       NaN  P994226       46007/3L  Ceiling Lights
# 34325  \nP994227       NaN  P994227        46007/6  Ceiling Lights
# 34326  \nP994228  443586.0  P994228      46007/6RC  Ceiling Lights
# 34327  \nP994229  427992.0  P994229        46008/1  Ceiling Lights
# 34328  \nP994230  429878.0  P994230        46008/3  Ceiling Lights
# 34329  \nP994231  626127.0  P994231       46008/3L  Ceiling Lights
# 34330  \nP994232       NaN  P994232        46008/6  Ceiling Lights
# 34331  \nP994233       NaN  P994233      46008/6RC  Ceiling Lights
# 34332  \nP994252  464454.0  P994252        46005/3  Ceiling Lights
# 34333  \nP994253  480693.0  P994253       46005/3L  Ceiling Lights
# 34334  \nP994254       NaN  P994254        46005/6  Ceiling Lights
# 34335  \nP994255  448007.0  P994255      46005/6RC  Ceiling Lights
# 34336         \n       NaN      NaN            NaN             NaN
#
#                   Category                  Type  \
# 34307  Mini-Pendant Lights   Mini-Pendant Lights
# 34308  Mini-Pendant Lights  Multi-Light Pendants
# 34309  Mini-Pendant Lights  Multi-Light Pendants
# 34310  Mini-Pendant Lights  Multi-Light Pendants
# 34311  Mini-Pendant Lights   Mini-Pendant Lights
# 34312  Mini-Pendant Lights  Multi-Light Pendants
# 34313  Mini-Pendant Lights  Multi-Light Pendants
# 34314  Mini-Pendant Lights  Multi-Light Pendants
# 34315  Mini-Pendant Lights   Mini-Pendant Lights
# 34316  Mini-Pendant Lights   Mini-Pendant Lights
# 34317  Mini-Pendant Lights   Mini-Pendant Lights
# 34318  Mini-Pendant Lights   Mini-Pendant Lights
# 34319  Mini-Pendant Lights  Multi-Light Pendants
# 34320  Mini-Pendant Lights  Multi-Light Pendants
# 34321  Mini-Pendant Lights  Multi-Light Pendants
# 34322  Mini-Pendant Lights   Mini-Pendant Lights
# 34323  Mini-Pendant Lights  Multi-Light Pendants
# 34324  Mini-Pendant Lights  Multi-Light Pendants
# 34325  Mini-Pendant Lights  Multi-Light Pendants
# 34326  Mini-Pendant Lights  Multi-Light Pendants
# 34327  Mini-Pendant Lights   Mini-Pendant Lights
# 34328  Mini-Pendant Lights  Multi-Light Pendants
# 34329  Mini-Pendant Lights  Multi-Light Pendants
# 34330  Mini-Pendant Lights  Multi-Light Pendants
# 34331  Mini-Pendant Lights  Multi-Light Pendants
# 34332  Mini-Pendant Lights  Multi-Light Pendants
# 34333  Mini-Pendant Lights  Multi-Light Pendants
# 34334  Mini-Pendant Lights  Multi-Light Pendants
# 34335  Mini-Pendant Lights  Multi-Light Pendants
# 34336                  NaN                   NaN
#
#                                            Product Title  \
# 34307                Mini-Pendant Light with Clear Glass
# 34308  Multi-Light Pendant Light with Clear Glass and...
# 34309  Multi-Light Pendant Light with Clear Glass and...
# 34310  Multi-Light Pendant Light with Clear Glass and...
# 34311                Mini-Pendant Light with Clear Glass
# 34312  Multi-Light Pendant Light with Clear Glass and...
# 34313  Multi-Light Pendant Light with Clear Glass and...
# 34314  Multi-Light Pendant Light with Clear Glass and...
# 34315                Mini-Pendant Light with Clear Glass
# 34316  Mini-Pendant Light with Clear Glass in Oiled B...
# 34317          Modern Mini-Pendant Light with Grey Glass
# 34318          Modern Mini-Pendant Light with Grey Glass
# 34319  Modern Multi-Light Pendant Light with Grey Gla...
# 34320  Modern Multi-Light Pendant Light with Grey Gla...
# 34321  Modern Multi-Light Pendant Light with Grey Gla...
# 34322              Mini-Pendant Light with Mercury Glass
# 34323  Multi-Light Pendant Light with Mercury Glass a...
# 34324  Multi-Light Pendant Light with Mercury Glass a...
# 34325  Multi-Light Pendant Light with Mercury Glass a...
# 34326  Multi-Light Pendant Light with Mercury Glass a...
# 34327  Elk Lighting Danica Mini-Pendant Light with Me...
# 34328  Multi-Light Pendant Light with Mercury Glass a...
# 34329  Multi-Light Pendant Light with Mercury Glass a...
# 34330  Multi-Light Pendant Light with Mercury Glass a...
# 34331  Multi-Light Pendant Light with Mercury Glass a...
# 34332  Multi-Light Pendant Light with White Glass and...
# 34333  Multi-Light Pendant Light with White Glass and...
# 34334  Multi-Light Pendant Light with White Glass and...
# 34335  Multi-Light Pendant Light with White Glass and...
# 34336                                                NaN
#
#                     Finish1   Treatment Hanging Method  Shade Color  \
# 34307                Chrome    Polished      Cord Hung        Clear
# 34308                Chrome    Polished      Cord Hung        Clear
# 34309                Chrome    Polished      Cord Hung        Clear
# 34310                Chrome    Polished      Cord Hung        Clear
# 34311                Chrome    Polished      Cord Hung        Clear
# 34312                Chrome    Polished      Cord Hung        Clear
# 34313                Chrome    Polished      Cord Hung        Clear
# 34314                Chrome    Polished      Cord Hung        Clear
# 34315  Bronze / Brown Tones  Oil Rubbed      Stem Hung        Clear
# 34316  Bronze / Brown Tones  Oil Rubbed      Stem Hung        Clear
# 34317                Chrome    Polished      Cord Hung   Grey Tones
# 34318                Chrome    Polished      Cord Hung   Grey Tones
# 34319                Chrome    Polished      Cord Hung   Grey Tones
# 34320                Chrome    Polished      Cord Hung   Grey Tones
# 34321                Chrome    Polished      Cord Hung   Grey Tones
# 34322  Bronze / Brown Tones  Oil Rubbed      Cord Hung      Mercury
# 34323  Bronze / Brown Tones  Oil Rubbed      Cord Hung      Mercury
# 34324  Bronze / Brown Tones  Oil Rubbed      Cord Hung      Mercury
# 34325  Bronze / Brown Tones  Oil Rubbed      Cord Hung      Mercury
# 34326  Bronze / Brown Tones  Oil Rubbed      Cord Hung      Mercury
# 34327  Bronze / Brown Tones  Oil Rubbed      Cord Hung      Mercury
# 34328  Bronze / Brown Tones  Oil Rubbed      Cord Hung      Mercury
# 34329  Bronze / Brown Tones  Oil Rubbed      Cord Hung      Mercury
# 34330  Bronze / Brown Tones  Oil Rubbed      Cord Hung      Mercury
# 34331  Bronze / Brown Tones  Oil Rubbed      Cord Hung      Mercury
# 34332  Bronze / Brown Tones  Oil Rubbed      Cord Hung  White Tones
# 34333  Bronze / Brown Tones  Oil Rubbed      Cord Hung  White Tones
# 34334  Bronze / Brown Tones  Oil Rubbed      Cord Hung  White Tones
# 34335  Bronze / Brown Tones  Oil Rubbed      Cord Hung  White Tones
# 34336                   NaN         NaN            NaN          NaN
#
#        Shade Shape                 Style1                 Style2 Style3  Tier
# 34307         Oval           Transitional  Contemporary / Modern    NaN   NaN
# 34308         Oval           Transitional  Contemporary / Modern    NaN   NaN
# 34309         Oval           Transitional  Contemporary / Modern    NaN   NaN
# 34310         Oval           Transitional  Contemporary / Modern    NaN   NaN
# 34311  Bowl / Dome           Transitional  Contemporary / Modern    NaN   NaN
# 34312  Bowl / Dome           Transitional  Contemporary / Modern    NaN   NaN
# 34313  Bowl / Dome           Transitional  Contemporary / Modern    NaN   NaN
# 34314  Bowl / Dome           Transitional  Contemporary / Modern    NaN   NaN
# 34315    Rectangle           Transitional  Contemporary / Modern    NaN   NaN
# 34316    Rectangle           Transitional  Contemporary / Modern    NaN   NaN
# 34317  Bowl / Dome  Contemporary / Modern                    NaN    NaN   NaN
# 34318  Bowl / Dome  Contemporary / Modern                    NaN    NaN   NaN
# 34319        Globe  Contemporary / Modern                    NaN    NaN   NaN
# 34320        Globe  Contemporary / Modern                    NaN    NaN   NaN
# 34321        Globe  Contemporary / Modern                    NaN    NaN   NaN
# 34322         Oval           Transitional  Contemporary / Modern    NaN   NaN
# 34323         Oval           Transitional  Contemporary / Modern    NaN   NaN
# 34324         Oval           Transitional  Contemporary / Modern    NaN   NaN
# 34325         Oval           Transitional  Contemporary / Modern    NaN   NaN
# 34326         Oval           Transitional  Contemporary / Modern    NaN   NaN
# 34327  Bowl / Dome           Transitional  Contemporary / Modern    NaN   NaN
# 34328  Bowl / Dome           Transitional  Contemporary / Modern    NaN   NaN
# 34329  Bowl / Dome           Transitional  Contemporary / Modern    NaN   NaN
# 34330  Bowl / Dome           Transitional  Contemporary / Modern    NaN   NaN
# 34331  Bowl / Dome           Transitional  Contemporary / Modern    NaN   NaN
# 34332  Cylindrical           Transitional                    NaN    NaN   NaN
# 34333  Cylindrical           Transitional                    NaN    NaN   NaN
# 34334  Cylindrical           Transitional                    NaN    NaN   NaN
# 34335  Cylindrical           Transitional                    NaN    NaN   NaN
# 34336          NaN                    NaN                    NaN    NaN   NaN

# %%
train.describe(include=['O'])
# Out:
#         ProductID      PID     VID      Department Category     Type  \
# count       34337    30855   34336           34336    34336    34281
# unique      34337    30850   34328               5       30       80
# top     \nP928445  P361673  203-09  Ceiling Lights  Sconces  Sconces
# freq            1        2       2           16216     4249     4231
#
#                                             Product Title  \
# count                                               34334
# unique                                              12659
# top     Modern Bathroom Light with White Glass in Sati...
# freq                                                  227
#
#                      Finish1 Treatment Hanging Method  Shade Color  \
# count                  33594     17883          12570        33343
# unique                    24        21              5           33
# top     Bronze / Brown Tones     Satin     Chain Hung  White Tones
# freq                   11728      4304           5334        12421
#
#         Shade Shape                 Style1        Style2        Style3
# count         24480                  33422         14283          2252
# unique           20                     26            26            26
# top     Bowl / Dome  Contemporary / Modern  Transitional  Transitional
# freq           5768                  13808          2547           421

# %%
excess_columns=set(["ProductID","EID","PID","VID","Department","Product Title","Category"])
train_researsh_columns=set(train.columns)-excess_columns
for ColumnName in train_researsh_columns: 
    Column=train[ColumnName] # train[ColumnIndex] не работает с groupby
    Column.groupby(Column).count().plot(kind="bar")
    plt.show()

# %%
def delete_rare_records(treshold):
    global train
    e = train['Tier'].value_counts()
    train=train[train['Tier'].isin(e[e>treshold].index)]
delete_rare_records(5)
Column=train[train.columns[16]] 
Column.groupby(Column).count().plot(kind="bar")
plt.show()
# Out:
# 1.0    3378
# 2.0     364
# 3.0      72
# 4.0       3
# Name: Tier, dtype: int64

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
# Out:
# Using TensorFlow backend.

# %%
создание модели

# %%
img_width, img_height = 150, 150

train_data_dir = 'data/train'
validation_data_dir = 'data/validation'
nb_train_samples = 2000
nb_validation_samples = 800
epochs = 50
batch_size = 16

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
metrics=['accuracy'])

# %% [markdown]
# как мы будем тренировать

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=40,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)

model.save_weights('first_try.h5')
